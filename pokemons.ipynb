# %% [markdown]
# # 📝 Pokémon
#
# Neste notebook você vai praticar Pandas usando dados de Pokémon.
# Use o exemplo do tutorial anterior para ajudá-lo a preencher os códigos.

# %% [markdown]
# ## Arquivo base
# O CSV `pokemon.csv` contém colunas como `Name`, `Type 1`, `Type 2`, `Total`, `HP`, `Attack`, `Defense`, `Sp. Atk`, `Sp. Def`, `Speed`, `Generation`, `Legendary`.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/lukas-senai/pandas-tutorial/main/assets/pokemons.csv"
df = pd.read_csv(url)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## 2️⃣ Seleção de colunas
# - Mostrar apenas a coluna `Name`
# - Mostrar as colunas `Name` e `Type 1`

# %%
df = pd.read_csv(url)
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df = pd.read_csv(url)
df[['Name' , 'Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %% [markdown]
# ## 3️⃣ Filtrando dados
# - Mostrar todos os Pokémon do tipo "Water"
# - Mostrar todos os Pokémon da Geração 1
# - Mostrar todos os Pokémon com HP maior que 70
# - Mostrar Pokémon com Attack >= 100
# - Filtrar apenas Pokémon Legendary (Legendary == True)

# %%
pokemon_agua = df[(df['Type 1'] == 'Water') | (df['Type 2'] == 'Water')]

pokemon_gen1 = df[df['Generation'] == 1]

pokemon_HP = df[df['HP'] > 70]

pokemon_ataque = df[df['Attack'] >= 100]

pokemon_legendario = df[df['Legendary'] == True]

pokemon_legendario
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 2      3               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 787  711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 788  712               Bergmite     Ice     NaN    304  55      69       85
# 789  713                Avalugg     Ice     NaN    514  95     117      184
# 790  714                 Noibat  Flying  Dragon    245  40      30       35
# 791  715                Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
Pokemon_Água = df[(df['Type 1'] == 'Water') | (df['Type 2'] == 'Water')]
Pokemon_Água
# Out:
#        #                     Name  Type 1 Type 2  Total  HP  Attack  Defense  \
# 9      7                 Squirtle   Water    NaN    314  44      48       65
# 10     8                Wartortle   Water    NaN    405  59      63       80
# 11     9                Blastoise   Water    NaN    530  79      83      100
# 12     9  BlastoiseMega Blastoise   Water    NaN    630  79     103      120
# 59    54                  Psyduck   Water    NaN    320  50      52       48
# ..   ...                      ...     ...    ...    ...  ..     ...      ...
# 759  689               Barbaracle    Rock  Water    500  72     105      115
# 760  690                   Skrelp  Poison  Water    320  50      60       60
# 762  692                Clauncher   Water    NaN    330  50      53       62
# 763  693                Clawitzer   Water    NaN    500  71      73       88
# 799  721                Volcanion    Fire  Water    600  80     110      120
#
# ...

# %%
Gem_1 = df[df['Generation'] == 1]
Gem_1
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison    318   45      49
# 1      2                Ivysaur    Grass    Poison    405   60      62
# 2      3               Venusaur    Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur    Grass    Poison    625   80     100
# 4      4             Charmander     Fire       NaN    309   39      52
# ..   ...                    ...      ...       ...    ...  ...     ...
# 161  149              Dragonite   Dragon    Flying    600   91     134
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 165  151                    Mew  Psychic       NaN    600  100     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df['HP'] >= 70]
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 2      3                   Venusaur    Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625   80     100
# 6      6                  Charizard     Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# ..   ...                        ...      ...     ...    ...  ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 794  718           Zygarde50% Forme   Dragon  Ground    600  108     100
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[df['Attack'] >= 100]
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630  79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495  65     150
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## 4️⃣ Estatísticas simples
# - Calcular a média da coluna Total
# - Descobrir o maior Total
# - Descobrir o menor Total
# - Calcular a média de Attack dos Pokémons da Geração 1
# - Calcular a média de Attack dos Pokémons da Geração 6
# - Calcular a médie de HP dos Pokémons do tipo Fire
# - Calcular a médie de HP dos Pokémons do tipo Water

# %%
media_total = df['Total'].mean()

maior_total = df['Total'].max()

menor_total = df['Total'].min()

media_ataque_gen1 = df[df['Generation'] == 1]['Attack'].mean()

media_ataque_gen6 = df[df['Generation'] == 6]['Attack'].mean()

media_HP_fogo = df[(df['Type 1'] == 'Fire') | (df['Type 2'] == 'Fire')]['HP'].mean()

media_HP_agua = df[(df['Type 1'] == 'Water') | (df['Type 2'] == 'Water')]['HP'].mean()
media_HP_agua

# %%
media_total = df['Total'].mean()
media_total
# Out:
# np.float64(435.1025)

# %%
maior_total = df['Total'].max()
media_total
# Out:
# np.float64(435.1025)

# %%
menor_total = df['Total'].min()
menor_total
# Out:
# 180

# %%
media_ataque_gen1 = df[df['Generation'] == 1]['Attack'].mean()
media_ataque_gen1
# Out:
# np.float64(76.63855421686748)

# %%
media_ataque_gen6 = df[df['Generation'] == 6]['Attack'].mean()
media_ataque_gen6

# %%
media_HP_fogo = df[(df['Type 1'] == 'Fire') | (df['Type 2'] == 'Fire')]['HP'].mean()
media_HP_fogo

# %% [markdown]
# ## 5️⃣ Ordenação
# - Ordenar os Pokémon por Total do maior para o menor.
# - Ordenar os Pokémon por Speed do menor para o maior.

# %%
ordenados_por_total = df.sort_values(by='Total', ascending=False)

ordenados_por_velocidade = df.sort_values(by='Speed', ascending=True)
ordenados_por_velocidade

# %%
ordenados_por_total = df.sort_values(by='Total', ascending=False)
ordenados_por_total

# %% [markdown]
# ## 5️⃣ Exploração rápida
# - Contar quantos Pokémon são Legendary
# - Mostrar os 5 primeiros Pokémon do CSV

# %%
qtd_legendarios = df[df['Legendary'] == True].shape[0]
print(f"A quantidade de pokemons lendarios é :{qtd_legendarios}")
# Out:
# A quantidade de pokemons lendarios é :65

# %%
primeiros5 = df.head(5)
primeiros5
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## 🔹 Desafios (opcional)
# 1. Mostrar o Pokémon mais rápido (`Speed`)
# 2. Mostrar o Pokémon do tipo Fire com maior `Attack`
# 3. Mostrar o Pokémon do tipo Rock com maior `HP`
# 4. Listar os Pokémon Legendary da primeira geração
# 5. Escreva qual é o seu Pokémon favorito

# %%
pokemon_mais_rapido = df.loc[df['Speed'].idxmax()]
print(f"O pokemon mais rapido é: {pokemon_mais_rapido['Name']} com {pokemon_mais_rapido['Speed']} de velocidade.")
# Out:
# O pokemon mais rapido é: DeoxysSpeed Forme com 180 de velocidade.

# %%
pokemons_fire = df[df['Type 1'] == 'Fire']
pokemon_fire_maior_ataque = pokemons_fire.loc[pokemons_fire['Attack'].idxmax()]
print(f"O pokemon do tipo fogo com maior Attack é: {pokemon_fire_maior_ataque['Name']} com {pokemon_fire_maior_ataque['Attack']} de ataque.")
# Out:
# O Pokémon do tipo Fire com maior Attack é: BlazikenMega Blaziken com 160 de Attack.

# %%
pokemons_rock = df[df['Type 1'] == 'Rock']
pokemon_rock_maior_hp = pokemons_rock.loc[pokemons_rock['HP'].idxmax()]
print(f"O pokemon do tipo rocha com maior HP é: {pokemon_rock_maior_hp['Name']} com {pokemon_rock_maior_hp['HP']} de HP.")
# Out:
# O pokemon do tipo rocha com maior HP é: Aurorus com 123 de HP.

# %%
lendarios_primeira_geracao = df[(df['Generation'] == 1) & (df['Legendary'] == True)]
print("Pokemons lendarios da primeira geração:")
print(lendarios_primeira_geracao['Name'])

# %% [markdown]
# com certeza meu preferido é o gengar (tenho uma capinha do bichin)
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣤⡀⠀⠀⠀⠀⣤⣤⠲⠃⠀⠀⠀⠀⣤⡟⢹⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠸⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⠏⢻⡇⣠⢤⣿⣏⠁⣿⣀⣰⣤⣤⢟⣿⢟⣇⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀�